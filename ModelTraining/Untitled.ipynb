# %%
import pandas as pd
import numpy as np
import plotly as py
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("adult.csv")

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital-gain  capital-loss  hours-per-week         country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#        salary
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# country           0
# salary            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'country', 'salary'],
#       dtype='object')

# %%
df.set_axis(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
       'marital_status', 'occupation', 'relationship', 'race', 'sex',
       'capital_gain', 'capital_loss', 'hours_per_week', 'country', 'salary'], axis=1, inplace=True)

# %%
for i in df.columns:
    print("Unique categories in {} features is: \n{}\n\n\n".format(i, df[i].unique()))
# Out:
# Unique categories in age features is:
# [39 50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87]
#
#
#
# Unique categories in workclass features is:
# [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked']
#
#
#
# Unique categories in fnlwgt features is:
# [ 77516  83311 215646 ...  34066  84661 257302]
#
#
#
# Unique categories in education features is:
# [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
#
#
#
# Unique categories in education_num features is:
# [13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8]
#
#
#
# Unique categories in marital_status features is:
# [' Never-married' ' Married-civ-spouse' ' Divorced'
#  ' Married-spouse-absent' ' Separated' ' Married-AF-spouse' ' Widowed']
#
#
#
# Unique categories in occupation features is:
# [' Adm-clerical' ' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
#  ' Other-service' ' Sales' ' Craft-repair' ' Transport-moving'
#  ' Farming-fishing' ' Machine-op-inspct' ' Tech-support' ' ?'
#  ' Protective-serv' ' Armed-Forces' ' Priv-house-serv']
#
#
#
# Unique categories in relationship features is:
# [' Not-in-family' ' Husband' ' Wife' ' Own-child' ' Unmarried'
#  ' Other-relative']
#
#
#
# Unique categories in race features is:
# [' White' ' Black' ' Asian-Pac-Islander' ' Amer-Indian-Eskimo' ' Other']
#
#
#
# Unique categories in sex features is:
# [' Male' ' Female']
#
#
#
# Unique categories in capital_gain features is:
# [ 2174     0 14084  5178  5013  2407 14344 15024  7688 34095  4064  4386
#   7298  1409  3674  1055  3464  2050  2176   594 20051  6849  4101  1111
#   8614  3411  2597 25236  4650  9386  2463  3103 10605  2964  3325  2580
#   3471  4865 99999  6514  1471  2329  2105  2885 25124 10520  2202  2961
#  27828  6767  2228  1506 13550  2635  5556  4787  3781  3137  3818  3942
#    914   401  2829  2977  4934  2062  2354  5455 15020  1424  3273 22040
#   4416  3908 10566   991  4931  1086  7430  6497   114  7896  2346  3418
#   3432  2907  1151  2414  2290 15831 41310  4508  2538  3456  6418  1848
#   3887  5721  9562  1455  2036  1831 11678  2936  2993  7443  6360  1797
#   1173  4687  6723  2009  6097  2653  1639 18481  7978  2387  5060]
#
#
#
# Unique categories in capital_loss features is:
# [   0 2042 1408 1902 1573 1887 1719 1762 1564 2179 1816 1980 1977 1876
#  1340 2206 1741 1485 2339 2415 1380 1721 2051 2377 1669 2352 1672  653
#  2392 1504 2001 1590 1651 1628 1848 1740 2002 1579 2258 1602  419 2547
#  2174 2205 1726 2444 1138 2238  625  213 1539  880 1668 1092 1594 3004
#  2231 1844  810 2824 2559 2057 1974  974 2149 1825 1735 1258 2129 2603
#  2282  323 4356 2246 1617 1648 2489 3770 1755 3683 2267 2080 2457  155
#  3900 2201 1944 2467 2163 2754 2472 1411]
#
#
#
# Unique categories in hours_per_week features is:
# [40 13 16 45 50 80 30 35 60 20 52 44 15 25 38 43 55 48 58 32 70  2 22 56
#  41 28 36 24 46 42 12 65  1 10 34 75 98 33 54  8  6 64 19 18 72  5  9 47
#  37 21 26 14  4 59  7 99 53 39 62 57 78 90 66 11 49 84  3 17 68 27 85 31
#  51 77 63 23 87 88 73 89 97 94 29 96 67 82 86 91 81 76 92 61 74 95]
#
#
#
# Unique categories in country features is:
# [' United-States' ' Cuba' ' Jamaica' ' India' ' ?' ' Mexico' ' South'
#  ' Puerto-Rico' ' Honduras' ' England' ' Canada' ' Germany' ' Iran'
#  ' Philippines' ' Italy' ' Poland' ' Columbia' ' Cambodia' ' Thailand'
#  ' Ecuador' ' Laos' ' Taiwan' ' Haiti' ' Portugal' ' Dominican-Republic'
#  ' El-Salvador' ' France' ' Guatemala' ' China' ' Japan' ' Yugoslavia'
#  ' Peru' ' Outlying-US(Guam-USVI-etc)' ' Scotland' ' Trinadad&Tobago'
#  ' Greece' ' Nicaragua' ' Vietnam' ' Hong' ' Ireland' ' Hungary'
#  ' Holand-Netherlands']
#
#
#
# Unique categories in salary features is:
# [' <=50K' ' >50K']

# %%
df.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital_gain  capital_loss  hours_per_week         country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#        salary
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 15 columns]

# %%
index_lis = set()
for i in range(32561):
    for j in range(15):
        if df.iloc[i][j] == ' ?':
            index_lis.add(df.index[i])

# %%
df.shape
# Out:
# (32561, 15)

# %%
len(index_lis)
# Out:
# 2399

# %%
df.drop(index=index_lis, inplace=True)

# %%
df.shape
# Out:
# (30162, 15)

# %%
df.duplicated().sum()
# Out:
# 23

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (30139, 15)

# %%
df.reset_index(drop=True, inplace=True)

# %%
for i in df.columns:
    print("Unique categories in {} features is: \n{}\n\n\n".format(i, df[i].unique()))
# Out:
# Unique categories in age features is:
# [39 50 38 53 28 37 49 52 31 42 30 23 32 34 25 43 40 54 35 59 56 19 20 45
#  22 48 21 24 57 44 41 29 47 46 36 79 27 18 33 76 55 61 70 64 71 66 51 58
#  26 17 60 90 75 65 77 62 63 67 74 72 69 68 73 81 78 88 80 84 83 85 82 86]
#
#
#
# Unique categories in workclass features is:
# [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' Self-emp-inc' ' Without-pay']
#
#
#
# Unique categories in fnlwgt features is:
# [ 77516  83311 215646 ...  84661 257302 201490]
#
#
#
# Unique categories in education features is:
# [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' 7th-8th' ' Doctorate' ' Assoc-voc' ' Prof-school'
#  ' 5th-6th' ' 10th' ' Preschool' ' 12th' ' 1st-4th']
#
#
#
# Unique categories in education_num features is:
# [13  9  7 14  5 10 12  4 16 11 15  3  6  1  8  2]
#
#
#
# Unique categories in marital_status features is:
# [' Never-married' ' Married-civ-spouse' ' Divorced'
#  ' Married-spouse-absent' ' Separated' ' Married-AF-spouse' ' Widowed']
#
#
#
# Unique categories in occupation features is:
# [' Adm-clerical' ' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
#  ' Other-service' ' Sales' ' Transport-moving' ' Farming-fishing'
#  ' Machine-op-inspct' ' Tech-support' ' Craft-repair' ' Protective-serv'
#  ' Armed-Forces' ' Priv-house-serv']
#
#
#
# Unique categories in relationship features is:
# [' Not-in-family' ' Husband' ' Wife' ' Own-child' ' Unmarried'
#  ' Other-relative']
#
#
#
# Unique categories in race features is:
# [' White' ' Black' ' Asian-Pac-Islander' ' Amer-Indian-Eskimo' ' Other']
#
#
#
# Unique categories in sex features is:
# [' Male' ' Female']
#
#
#
# Unique categories in capital_gain features is:
# [ 2174     0 14084  5178  5013  2407 14344 15024  7688  4064  4386  7298
#   1409  3674  1055  2050  2176   594 20051  6849  4101  8614  3411  2597
#  25236  4650  2463  3103 10605  2964  3325  2580  3471  4865 99999  6514
#   1471  2329  2105  2885 10520  2202  2961 27828  6767  2228  1506 13550
#   2635  5556  4787  3781  3137  3818   914   401  2829  2977  4934  2062
#   2354  3464  5455 15020  1424  3273 22040  4416 10566  4931  7430 34095
#   6497  3908   114  2346  2907  1151  9386  2414  2290  3418 15831 41310
#   4508  2538  3456  1848  3887  7896  5721  9562  6418  1455  2036  3942
#   1831 11678  2936  2993  7443  6360  4687  1797  6723  2009  3432  6097
#   1639  2653 18481 25124  7978   991  1173  2387  5060  1086]
#
#
#
# Unique categories in capital_loss features is:
# [   0 2042 1408 1902 1887 1719 1762 1564 2179 1816 1980 1977 1876 1340
#  2206 1741 1485 2339 2415 1380 1721 2051 2377 1669 2352 1672  653 2392
#  1504 1590 1651 1628 1848 2001 1740 2002 1579 2258 1602 2547 2205 1726
#  2444 1138 2238  625  213 1539  880 1668 1092 1594 2231 1844  810 2824
#  2559 2057 1573 1974  974 2174 2149 1735 1258 2603 2282  323 2246 1617
#  1648 1825 3770 1755 3683 2129 4356 2267 2080 2457  419  155 3900 2201
#  1944 2467 2754 2472 3004 1411]
#
#
#
# Unique categories in hours_per_week features is:
# [40 13 16 45 50 80 30 35 60 20 52 44 15 25 43 38 55 48 58 32 70 22 56 41
#  28 36 24 46  2 42 12 65  1 34 75 98 33 54 10  6 64 19 18 72  8  9 47 37
#  21 26 14  5  7 99 53 39 62 59 57 78 90 66 11 49 84 17 68  3 27 85 31 51
#  77 63 23  4 87 88 73 89 97 94 29 96 67 82 86 91 81 76 92 61 74 95]
#
#
#
# Unique categories in country features is:
# [' United-States' ' Cuba' ' Jamaica' ' India' ' Mexico' ' Puerto-Rico'
#  ' Honduras' ' England' ' Canada' ' Germany' ' Iran' ' Philippines'
#  ' Poland' ' Columbia' ' Cambodia' ' Thailand' ' Ecuador' ' Laos'
#  ' Taiwan' ' Haiti' ' Portugal' ' Dominican-Republic' ' El-Salvador'
#  ' France' ' Guatemala' ' Italy' ' China' ' South' ' Japan' ' Yugoslavia'
#  ' Peru' ' Outlying-US(Guam-USVI-etc)' ' Scotland' ' Trinadad&Tobago'
#  ' Greece' ' Nicaragua' ' Vietnam' ' Hong' ' Ireland' ' Hungary'
#  ' Holand-Netherlands']
#
#
#
# Unique categories in salary features is:
# [' <=50K' ' >50K']

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 30134   27            Private  257302   Assoc-acdm             12
# 30135   40            Private  154374      HS-grad              9
# 30136   58            Private  151910      HS-grad              9
# 30137   22            Private  201490      HS-grad              9
# 30138   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 30134   Married-civ-spouse        Tech-support            Wife   White
# 30135   Married-civ-spouse   Machine-op-inspct         Husband   White
# 30136              Widowed        Adm-clerical       Unmarried   White
# 30137        Never-married        Adm-clerical       Own-child   White
# 30138   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital_gain  capital_loss  hours_per_week         country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 30134   Female             0             0              38   United-States
# 30135     Male             0             0              40   United-States
# 30136   Female             0             0              40   United-States
# 30137     Male             0             0              20   United-States
# 30138   Female         15024             0              40   United-States
#
#        salary
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 30134   <=50K
# 30135    >50K
# 30136   <=50K
# 30137   <=50K
# 30138    >50K
#
# [30139 rows x 15 columns]

# %%
df.salary.unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
df.replace({' >50K': 1, ' <=50K': 0}, inplace=True)

# %%
df.replace({' Male': 0, ' Female': 1}, inplace=True)

# %%
plt.figure(figsize=(15,15))
sns.catplot(x='workclass', y='salary', data=df, kind='bar',  height=7,aspect=2)
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.catplot(x='education', y='salary', data=df, kind='bar',  height=7,aspect=2)
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.catplot(x='marital_status', y='salary', data=df, kind='bar', height=7,aspect=2)
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.catplot(x='occupation', y='salary', data=df, kind='bar', height=10,aspect=4)
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.catplot(x='relationship', y='salary', data=df, kind='bar', height=7,aspect=2)
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.catplot(x='race', y='salary', data=df, kind='bar', height=7,aspect=2)
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.catplot(x='sex', y='salary', data=df, kind='bar', height=7,aspect=2)
plt.show()

# %%
plt.figure(figsize=(50,50))
sns.catplot(x='country', y='salary', data=df, kind='bar', height=7,aspect=4)
plt.show()

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex                int64
# capital_gain       int64
# capital_loss       int64
# hours_per_week     int64
# country           object
# salary             int64
# dtype: object

# %%
df.country.unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' Mexico',
#        ' Puerto-Rico', ' Honduras', ' England', ' Canada', ' Germany',
#        ' Iran', ' Philippines', ' Poland', ' Columbia', ' Cambodia',
#        ' Thailand', ' Ecuador', ' Laos', ' Taiwan', ' Haiti', ' Portugal',
#        ' Dominican-Republic', ' El-Salvador', ' France', ' Guatemala',
#        ' Italy', ' China', ' South', ' Japan', ' Yugoslavia', ' Peru',
#        ' Outlying-US(Guam-USVI-etc)', ' Scotland', ' Trinadad&Tobago',
#        ' Greece', ' Nicaragua', ' Vietnam', ' Hong', ' Ireland',
#        ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
east_Asia = [" Cambodia", " Philippines", " China", " Hong", " Laos", " Thailand"," Japan", " Taiwan", " Vietnam"]
central_America = [" Cuba", " Guatemala", " Jamaica", " Nicaragua", " Puerto-Rico",  " Dominican-Republic", " El-Salvador", " Haiti", " Honduras", " Mexico", " Trinadad&Tobago"]
west_Europe = [" England", " Germany", " Holand-Netherlands", " Ireland", " France", " Greece", " Italy", " Portugal", " Scotland"]
central_Asia = [" India", " Iran"]
south_America = [" Ecuador", " Peru", " Columbia"]
north_America = [' United-States', ' Canada', ' Outlying-US(Guam-USVI-etc)']
east_Europe = [" Poland", " Yugoslavia", " Hungary"]
south_Asia = [' South']

# %%
df.replace(to_replace=east_Asia,value="East_Asia",inplace=True)
df.replace(to_replace=central_America,value="central_America",inplace=True)
df.replace(to_replace=west_Europe,value="west_Europe",inplace=True)
df.replace(to_replace=north_America,value="north_America",inplace=True)
df.replace(to_replace=central_Asia,value="central_Asia",inplace=True)
df.replace(to_replace=south_America,value="south_America",inplace=True)
df.replace(to_replace=east_Europe,value="east_Europe",inplace=True)
df.replace(to_replace=south_Asia,value="south_Asia",inplace=True)

# %%
df.country.unique()
# Out:
# array(['north_America', 'central_America', 'central_Asia', 'west_Europe',
#        'East_Asia', 'east_Europe', 'south_America', 'south_Asia'],
#       dtype=object)

# %%
df.race.unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
df[df['country'] == " South"]
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education_num, marital_status, occupation, relationship, race, sex, capital_gain, capital_loss, hours_per_week, country, salary]
# Index: []

# %%
plt.figure(figsize=(50,30))
sns.catplot(x='country',y='salary', data=df.sort_values('salary', ascending=False), kind='bar', height=7,aspect=2)
plt.show()

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 30134   27            Private  257302   Assoc-acdm             12
# 30135   40            Private  154374      HS-grad              9
# 30136   58            Private  151910      HS-grad              9
# 30137   22            Private  201490      HS-grad              9
# 30138   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  sex  \
# 0            Never-married        Adm-clerical   Not-in-family   White    0
# 1       Married-civ-spouse     Exec-managerial         Husband   White    0
# 2                 Divorced   Handlers-cleaners   Not-in-family   White    0
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black    0
# 4       Married-civ-spouse      Prof-specialty            Wife   Black    1
# ...                    ...                 ...             ...     ...  ...
# 30134   Married-civ-spouse        Tech-support            Wife   White    1
# 30135   Married-civ-spouse   Machine-op-inspct         Husband   White    0
# 30136              Widowed        Adm-clerical       Unmarried   White    1
# 30137        Never-married        Adm-clerical       Own-child   White    0
# 30138   Married-civ-spouse     Exec-managerial            Wife   White    1
#
#        capital_gain  capital_loss  hours_per_week          country  salary
# 0              2174             0              40    north_America       0
# 1                 0             0              13    north_America       0
# 2                 0             0              40    north_America       0
# 3                 0             0              40    north_America       0
# 4                 0             0              40  central_America       0
# ...             ...           ...             ...              ...     ...
# 30134             0             0              38    north_America       0
# 30135             0             0              40    north_America       1
# 30136             0             0              40    north_America       0
# 30137             0             0              20    north_America       0
# 30138         15024             0              40    north_America       1
#
# [30139 rows x 15 columns]

# %%
temp_df = df.drop(['age', 'fnlwgt', 'education_num', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'salary'], axis=1)

# %%
temp_df
# Out:
#                workclass    education       marital_status  \
# 0              State-gov    Bachelors        Never-married
# 1       Self-emp-not-inc    Bachelors   Married-civ-spouse
# 2                Private      HS-grad             Divorced
# 3                Private         11th   Married-civ-spouse
# 4                Private    Bachelors   Married-civ-spouse
# ...                  ...          ...                  ...
# 30134            Private   Assoc-acdm   Married-civ-spouse
# 30135            Private      HS-grad   Married-civ-spouse
# 30136            Private      HS-grad              Widowed
# 30137            Private      HS-grad        Never-married
# 30138       Self-emp-inc      HS-grad   Married-civ-spouse
#
#                occupation    relationship    race          country
# 0            Adm-clerical   Not-in-family   White    north_America
# 1         Exec-managerial         Husband   White    north_America
# 2       Handlers-cleaners   Not-in-family   White    north_America
# 3       Handlers-cleaners         Husband   Black    north_America
# 4          Prof-specialty            Wife   Black  central_America
# ...                   ...             ...     ...              ...
# 30134        Tech-support            Wife   White    north_America
# 30135   Machine-op-inspct         Husband   White    north_America
# 30136        Adm-clerical       Unmarried   White    north_America
# 30137        Adm-clerical       Own-child   White    north_America
# 30138     Exec-managerial            Wife   White    north_America
#
# [30139 rows x 7 columns]

# %%
temp_df.education.unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' 7th-8th', ' Doctorate',
#        ' Assoc-voc', ' Prof-school', ' 5th-6th', ' 10th', ' Preschool',
#        ' 12th', ' 1st-4th'], dtype=object)

# %%
plt.figure(figsize=(50,30))
sns.catplot(x='education',y='salary', data=df.sort_values('salary', ascending=False), kind='bar', height=7,aspect=2)
plt.show()

# %%
'''education_mapping = {' Bachelors':13, ' HS-grad':9, ' 11th':7, ' Masters':14, ' 9th':5,
       ' Some-college':10, ' Assoc-acdm':12, ' 7th-8th':4, ' Doctorate':16,
       ' Assoc-voc':11, ' Prof-school':15, ' 5th-6th':3, ' 10th':6, ' Preschool':1,
       ' 12th':8, ' 1st-4th':2}
df['education_ord'] = temp_df.education.map(education_mapping)
df.head(5)'''
# Out:
# "education_mapping = {' Bachelors':13, ' HS-grad':9, ' 11th':7, ' Masters':14, ' 9th':5,\n       ' Some-college':10, ' Assoc-acdm':12, ' 7th-8th':4, ' Doctorate':16,\n       ' Assoc-voc':11, ' Prof-school':15, ' 5th-6th':3, ' 10th':6, ' Preschool':1,\n       ' 12th':8, ' 1st-4th':2}\ndf['education_ord'] = temp_df.education.map(education_mapping)\ndf.head(5)"

# %%
df[df['education'] == ' Preschool']['education_num']
# Out:
# 208      1
# 857      1
# 2648     1
# 2705     1
# 3166     1
# 3767     1
# 5916     1
# 6322     1
# 6517     1
# 7281     1
# 7450     1
# 8103     1
# 9527     1
# 10291    1
# 10495    1
# 12252    1
# 15270    1
# 15331    1
# 17059    1
# 18934    1
# 19794    1
# 19811    1
# 20182    1
# 20526    1
# 20864    1
# 21244    1
# 22392    1
# 22754    1
# 22883    1
# 23247    1
# 23258    1
# 23365    1
# 23755    1
# 24023    1
# 24540    1
# 24635    1
# 25144    1
# 25228    1
# 26298    1
# 29434    1
# 29656    1
# 29829    1
# 29953    1
# 30023    1
# Name: education_num, dtype: int64

# %%
temp_df.drop('education', axis=1, inplace=True)

# %%
temp_df
# Out:
#                workclass       marital_status          occupation  \
# 0              State-gov        Never-married        Adm-clerical
# 1       Self-emp-not-inc   Married-civ-spouse     Exec-managerial
# 2                Private             Divorced   Handlers-cleaners
# 3                Private   Married-civ-spouse   Handlers-cleaners
# 4                Private   Married-civ-spouse      Prof-specialty
# ...                  ...                  ...                 ...
# 30134            Private   Married-civ-spouse        Tech-support
# 30135            Private   Married-civ-spouse   Machine-op-inspct
# 30136            Private              Widowed        Adm-clerical
# 30137            Private        Never-married        Adm-clerical
# 30138       Self-emp-inc   Married-civ-spouse     Exec-managerial
#
#          relationship    race          country
# 0       Not-in-family   White    north_America
# 1             Husband   White    north_America
# 2       Not-in-family   White    north_America
# 3             Husband   Black    north_America
# 4                Wife   Black  central_America
# ...               ...     ...              ...
# 30134            Wife   White    north_America
# 30135         Husband   White    north_America
# 30136       Unmarried   White    north_America
# 30137       Own-child   White    north_America
# 30138            Wife   White    north_America
#
# [30139 rows x 6 columns]

# %%
temp_df.workclass.unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' Self-emp-inc', ' Without-pay'], dtype=object)

# %%
var_map = dict()
for i in temp_df.columns:
    var_map = temp_df[i].value_counts().to_dict()
    print(var_map)
    temp_df[i] = temp_df[i].map(var_map)
# Out:
# {' Private': 22264, ' Self-emp-not-inc': 2498, ' Local-gov': 2067, ' State-gov': 1279, ' Self-emp-inc': 1074, ' Federal-gov': 943, ' Without-pay': 14}
# {' Married-civ-spouse': 14059, ' Never-married': 9711, ' Divorced': 4212, ' Separated': 939, ' Widowed': 827, ' Married-spouse-absent': 370, ' Married-AF-spouse': 21}
# {' Prof-specialty': 4034, ' Craft-repair': 4025, ' Exec-managerial': 3991, ' Adm-clerical': 3719, ' Sales': 3584, ' Other-service': 3209, ' Machine-op-inspct': 1964, ' Transport-moving': 1572, ' Handlers-cleaners': 1349, ' Farming-fishing': 987, ' Tech-support': 911, ' Protective-serv': 644, ' Priv-house-serv': 141, ' Armed-Forces': 9}
# {' Husband': 12457, ' Not-in-family': 7714, ' Own-child': 4462, ' Unmarried': 3211, ' Wife': 1406, ' Other-relative': 889}
# {' White': 25912, ' Black': 2816, ' Asian-Pac-Islander': 894, ' Amer-Indian-Eskimo': 286, ' Other': 231}
# {'north_America': 27608, 'central_America': 1220, 'East_Asia': 492, 'west_Europe': 408, 'central_Asia': 142, 'south_America': 113, 'east_Europe': 85, 'south_Asia': 71}

# %%
temp_df.head(10)
# Out:
#    workclass  marital_status  occupation  relationship   race  country
# 0       1279            9711        3719          7714  25912    27608
# 1       2498           14059        3991         12457  25912    27608
# 2      22264            4212        1349          7714  25912    27608
# 3      22264           14059        1349         12457   2816    27608
# 4      22264           14059        4034          1406   2816     1220
# 5      22264           14059        3991          1406  25912    27608
# 6      22264             370        3209          7714   2816     1220
# 7       2498           14059        3991         12457  25912    27608
# 8      22264            9711        4034          7714  25912    27608
# 9      22264           14059        3991         12457  25912    27608

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 30134   27            Private  257302   Assoc-acdm             12
# 30135   40            Private  154374      HS-grad              9
# 30136   58            Private  151910      HS-grad              9
# 30137   22            Private  201490      HS-grad              9
# 30138   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  sex  \
# 0            Never-married        Adm-clerical   Not-in-family   White    0
# 1       Married-civ-spouse     Exec-managerial         Husband   White    0
# 2                 Divorced   Handlers-cleaners   Not-in-family   White    0
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black    0
# 4       Married-civ-spouse      Prof-specialty            Wife   Black    1
# ...                    ...                 ...             ...     ...  ...
# 30134   Married-civ-spouse        Tech-support            Wife   White    1
# 30135   Married-civ-spouse   Machine-op-inspct         Husband   White    0
# 30136              Widowed        Adm-clerical       Unmarried   White    1
# 30137        Never-married        Adm-clerical       Own-child   White    0
# 30138   Married-civ-spouse     Exec-managerial            Wife   White    1
#
#        capital_gain  capital_loss  hours_per_week          country  salary
# 0              2174             0              40    north_America       0
# 1                 0             0              13    north_America       0
# 2                 0             0              40    north_America       0
# 3                 0             0              40    north_America       0
# 4                 0             0              40  central_America       0
# ...             ...           ...             ...              ...     ...
# 30134             0             0              38    north_America       0
# 30135             0             0              40    north_America       1
# 30136             0             0              40    north_America       0
# 30137             0             0              20    north_America       0
# 30138         15024             0              40    north_America       1
#
# [30139 rows x 15 columns]

# %%
df.drop(['workclass', 'education', 'marital_status', 'occupation', 'relationship', 'race', 'country'], axis=1, inplace=True)

# %%
df = pd.concat([df, temp_df], axis=1)

# %%
df
# Out:
#        age  fnlwgt  education_num  sex  capital_gain  capital_loss  \
# 0       39   77516             13    0          2174             0
# 1       50   83311             13    0             0             0
# 2       38  215646              9    0             0             0
# 3       53  234721              7    0             0             0
# 4       28  338409             13    1             0             0
# ...    ...     ...            ...  ...           ...           ...
# 30134   27  257302             12    1             0             0
# 30135   40  154374              9    0             0             0
# 30136   58  151910              9    1             0             0
# 30137   22  201490              9    0             0             0
# 30138   52  287927              9    1         15024             0
#
#        hours_per_week  salary  workclass  marital_status  occupation  \
# 0                  40       0       1279            9711        3719
# 1                  13       0       2498           14059        3991
# 2                  40       0      22264            4212        1349
# 3                  40       0      22264           14059        1349
# 4                  40       0      22264           14059        4034
# ...               ...     ...        ...             ...         ...
# 30134              38       0      22264           14059         911
# 30135              40       1      22264           14059        1964
# 30136              40       0      22264             827        3719
# 30137              20       0      22264            9711        3719
# 30138              40       1       1074           14059        3991
#
#        relationship   race  country
# 0              7714  25912    27608
# 1             12457  25912    27608
# 2              7714  25912    27608
# 3             12457   2816    27608
# 4              1406   2816     1220
# ...             ...    ...      ...
# 30134          1406  25912    27608
# 30135         12457  25912    27608
# 30136          3211  25912    27608
# 30137          4462  25912    27608
# 30138          1406  25912    27608
#
# [30139 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['age', 'fnlwgt', 'education_num', 'sex', 'capital_gain', 'capital_loss',
#        'hours_per_week', 'salary', 'workclass', 'marital_status', 'occupation',
#        'relationship', 'race', 'country'],
#       dtype='object')

# %%
df.to_csv("df_with_relationship.csv", index=False)
df.to_csv("df_without_relationship.csv",index=False)
